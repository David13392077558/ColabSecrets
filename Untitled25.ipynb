# %% [markdown]
# ```json
# {
#   "compilerOptions": {
#     "target": "ESNext",
#     "useDefineForClassFields": true,
#     "lib": ["DOM", "DOM.Iterable", "ESNext"], // Ensure 'DOM' and 'DOM.Iterable' are included
#     "allowJs": false,
#     "skipLibCheck": true,
#     "esModuleInterop": false,
#     "allowSyntheticDefaultImports": true,
#     "strict": true,
#     "forceConsistentCasingInFileNames": true,
#     "module": "ESNext",
#     "moduleResolution": "Node",
#     "resolveJsonModule": true,
#     // "isolatedModules": true, // Often needed for Vite builds
#     "noEmit": true,
#     "jsx": "react-jsx", // Or 'react' if you're using classic runtime
#     "types": ["vite/client"] // Add this line to include Vite client types
#   },
#   "include": ["src"],
#   "references": [{ "path": "./tsconfig.node.json" }]
# }
# ```
#
# After making these changes, restart your TypeScript language server or your development server to ensure the new configuration is picked up. This should resolve the `Property 'env' does not exist on type 'ImportMeta'` error.
